# %% [markdown]
# # RLOO Training Runner
# code
# #VSC-44125f66
# python
# # Install dependencies if they are not already available
# # %pip install -r /kaggle/input/rloo/requirements.txt
#
# import sys
# from pathlib import Path
#
# DATASET_ROOT = Path('/kaggle/input/rloo')
# SRC_PATH = DATASET_ROOT / 'src'
# if SRC_PATH.exists():
#     sys.path.append(str(SRC_PATH))
#
# from scripts.kaggle_setup import ensure_output_dirs, setup_pythonpath
#
# setup_pythonpath(DATASET_ROOT)
# ensure_output_dirs()
# DATASET_ROOT
# code
# #VSC-71106bf1
# python
# from rloo_project.config import TrainingConfig
# from rloo_project.train_rloo import run_training
#
# config_path = DATASET_ROOT / 'configs' / 'default_training.yaml'
# config = TrainingConfig.from_yaml(config_path)
# config.run.output_dir = '/kaggle/working/rloo_runs/default'
#
# run_training(config)
